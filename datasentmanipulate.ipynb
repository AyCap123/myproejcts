# %% [markdown]
# # import pandas as pd
# ray=pd.read_csv(r'C:\Users\Ayan\Desktop\abcd.csv')
# print(ray)

# %%
ray.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41715 entries, 0 to 41714
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         41715 non-null  int64
#  1   Industry_aggregation_NZSIOC  41715 non-null  object
#  2   Industry_code_NZSIOC         41715 non-null  object
#  3   Industry_name_NZSIOC         41715 non-null  object
#  4   Units                        41715 non-null  object
#  5   Variable_code                41715 non-null  object
#  6   Variable_name                41715 non-null  object
#  7   Variable_category            41715 non-null  object
#  8   Value                        41715 non-null  object
#  9   Industry_code_ANZSIC06       41715 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.2+ MB
# ...

# %%
ray.count()
# Out:
# Year                           41715
# Industry_aggregation_NZSIOC    41715
# Industry_code_NZSIOC           41715
# Industry_name_NZSIOC           41715
# Units                          41715
# Variable_code                  41715
# Variable_name                  41715
# Variable_category              41715
# Value                          41715
# Industry_code_ANZSIC06         41715
# dtype: int64

# %%
ray.describe()
# Out:
#               Year
# count  41715.00000
# mean    2017.00000
# std        2.58202
# min     2013.00000
# 25%     2015.00000
# 50%     2017.00000
# 75%     2019.00000
# max     2021.00000

# %%
ray.std()
# Out:
# C:\Users\Ayan\AppData\Local\Temp\ipykernel_1872\871220526.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ray.std()
# Year    2.58202
# dtype: float64

# %%
ray.min()
# Out:
# Year                                                2013
# Industry_aggregation_NZSIOC                      Level 1
# Industry_code_NZSIOC                               99999
# Industry_name_NZSIOC                       Accommodation
# Units                                            Dollars
# Variable_code                                        H01
# Variable_name                  Additions to fixed assets
# Variable_category                  Financial performance
# Value                                                 -1
# Industry_code_ANZSIC06               ANZSIC06 Group F380
# dtype: object

# %%
ray.max()
# Out:
# Year                                                           2021
# Industry_aggregation_NZSIOC                                 Level 4
# Industry_code_NZSIOC                                           ZZ11
# Industry_name_NZSIOC                     Wood Product Manufacturing
# Units                                                    Percentage
# Variable_code                                                   H41
# Variable_name                       Total income per employee count
# Variable_category                                  Financial ratios
# Value                                                             S
# Industry_code_ANZSIC06         ANZSIC06 groups S951, S952, and S953
# dtype: object

# %%
ray.shape
# Out:
# (41715, 10)

# %%
ray.rename(columns={'Year':'Time Period'})
# Out:
#        Time Period Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0             2021                     Level 1                99999
# 1             2021                     Level 1                99999
# 2             2021                     Level 1                99999
# 3             2021                     Level 1                99999
# 4             2021                     Level 1                99999
# ...            ...                         ...                  ...
# 41710         2013                     Level 3                 ZZ11
# 41711         2013                     Level 3                 ZZ11
# 41712         2013                     Level 3                 ZZ11
# 41713         2013                     Level 3                 ZZ11
# 41714         2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...

# %%
ray.drop(columns={'Variable_code'})
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units  \
# 0                  All industries  Dollars (millions)
# 1                  All industries  Dollars (millions)
# 2                  All industries  Dollars (millions)
# ...

# %%
ray.iloc[0:4]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
# 3                             Non-operating income  Financial performance
#
# ...

# %%
ray.iloc[0:3,4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ray.iloc[0:3,4]
#
# NameError: name 'ray' is not defined

# %%
ray.loc[:,"Value"]
# Out:
# 0        757,504
# 1        674,890
# 2         49,593
# 3         33,020
# 4        654,404
#           ...
# 41710         52
# 41711         40
# 41712         12
# 41713          5
# 41714         46
# Name: Value, Length: 41715, dtype: object

# %%
ray.loc[:,"Year":"Value"]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd
yep=pd.read_csv(r'C:\Users\Ayan\Desktop\yoo.csv')
print(yep)
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
yep.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  307 non-null    int64
#  1   name                307 non-null    object
#  2   nationality         307 non-null    object
#  3   city                307 non-null    object
#  4   latitude            307 non-null    float64
#  5   longitude           307 non-null    float64
#  6   gender              307 non-null    object
#  7   ethnic.group        0 non-null      float64
#  8   age                 307 non-null    int64
#  9   english.grade       307 non-null    float64
#  10  math.grade          307 non-null    float64
#  11  sciences.grade      307 non-null    float64
#  12  language.grade      307 non-null    float64
#  13  portfolio.rating    307 non-null    int64
#  14  coverletter.rating  307 non-null    float64
# ...

# %%
yep.count()
# Out:
# id                    307
# name                  307
# nationality           307
# city                  307
# latitude              307
# longitude             307
# gender                307
# ethnic.group            0
# age                   307
# english.grade         307
# math.grade            307
# sciences.grade        307
# language.grade        307
# portfolio.rating      307
# coverletter.rating    307
# refletter.rating      307
# dtype: int64

# %%
yep.describe()
# Out:
#                id    latitude   longitude  ethnic.group         age  \
# count  307.000000  307.000000  307.000000           0.0  307.000000
# mean   153.000000   32.863388  -64.539121           NaN   21.964169
# std     88.767487   13.498582   81.249146           NaN    1.248013
# min      0.000000  -33.450000 -123.130000           NaN   19.000000
# 25%     76.500000   32.720000 -118.240000           NaN   21.000000
# 50%    153.000000   34.390000  -99.140000           NaN   22.000000
# 75%    229.500000   38.960000  -73.855000           NaN   23.000000
# max    306.000000   59.890000  139.750000           NaN   26.000000
#
#        english.grade  math.grade  sciences.grade  language.grade  \
# count     307.000000  307.000000      307.000000      307.000000
# mean        3.369707    3.414332        3.446580        4.396417
# std         0.538724    0.476839        0.509081        0.996474
# min         1.500000    2.100000        1.400000        1.000000
# ...

# %%
yep.shape
# Out:
# (307, 16)

# %%
yep.std()
# Out:
# C:\Users\Ayan\AppData\Local\Temp\ipykernel_8696\5812200.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   yep.std()
# id                    88.767487
# latitude              13.498582
# longitude             81.249146
# ethnic.group                NaN
# age                    1.248013
# english.grade          0.538724
# math.grade             0.476839
# sciences.grade         0.509081
# language.grade         0.996474
# portfolio.rating       0.928749
# coverletter.rating     0.823936
# refletter.rating       0.842193
# dtype: float64

# %%
yep.min()
# Out:
# id                                   0
# name                  Aaqil el-Hashemi
# nationality                 Bangladesh
# city                    Aguascalientes
# latitude                        -33.45
# longitude                      -123.13
# gender                               F
# ethnic.group                       NaN
# age                                 19
# english.grade                      1.5
# math.grade                         2.1
# sciences.grade                     1.4
# language.grade                     1.0
# portfolio.rating                     1
# coverletter.rating                 1.0
# refletter.rating                     1
# dtype: object

# %%
yep.max()
# Out:
# id                                         306
# name                                  Zoe Kern
# nationality           United States of America
# city                                   Zülpich
# latitude                                 59.89
# longitude                               139.75
# gender                                   other
# ethnic.group                               NaN
# age                                         26
# english.grade                              4.0
# math.grade                                 4.0
# sciences.grade                             4.0
# language.grade                             5.0
# portfolio.rating                             5
# coverletter.rating                         5.0
# refletter.rating                             5
# dtype: object

# %%
yep.rename(columns={'nationality':'NA'})
# Out:
#       id               name                        NA                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
yep.drop(columns={'longitude'})
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
yep.iloc[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 yep.iloc[:]
#
# NameError: name 'yep' is not defined

# %%
yep.iloc[0:3,5]
# Out:
# 0    120.62
# 1   -118.54
# 2   -122.27
# Name: longitude, dtype: float64

# %%
yep.loc[:,"longitude"]
# Out:
# 0      120.62
# 1     -118.54
# 2     -122.27
# 3     -122.09
# 4      -45.88
#         ...
# 302    -83.00
# 303   -118.24
# 304   -118.24
# 305   -122.27
# 306    -79.42
# Name: longitude, Length: 307, dtype: float64

# %%
yep.loc[0:5,"id":"longitude"]
# Out:
#    id              name               nationality                 city  \
# 0   0         Kiana Lor                     China               Suzhou
# 1   1    Joshua Lonaker  United States of America        Santa Clarita
# 2   2     Dakota Blanco  United States of America              Oakland
# 3   3   Natasha Yarusso  United States of America        Castro Valley
# 4   4    Brooke Cazares                    Brazil  São José dos Campos
# 5   5  Rochelle Johnson  United States of America         Indianapolis
#
#    latitude  longitude
# 0     31.31     120.62
# 1     34.39    -118.54
# 2     37.80    -122.27
# 3     37.69    -122.09
# 4    -23.18     -45.88
# 5     39.77     -86.16

# %%
print("type-",type(yep))
# Out:
# type- <class 'pandas.core.frame.DataFrame'>

# %%
yep.head(10) #prints no of rows
# Out:
#    id              name               nationality                 city  \
# 0   0         Kiana Lor                     China               Suzhou
# 1   1    Joshua Lonaker  United States of America        Santa Clarita
# 2   2     Dakota Blanco  United States of America              Oakland
# 3   3   Natasha Yarusso  United States of America        Castro Valley
# 4   4    Brooke Cazares                    Brazil  São José dos Campos
# 5   5  Rochelle Johnson  United States of America         Indianapolis
# 6   6        Joey Abreu                     China             Shenyang
# 7   7    Preston Suarez                    Brazil            São Paulo
# 8   8          Lee Dong               Philippines               Manila
# 9   9     Maa'iz al-Dia                    Turkey             Istanbul
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# ...

# %%
yep.shape
# Out:
# (307, 16)

# %%
yep.dropna() #drops everything where valuue is absent
# Out:
# Empty DataFrame
# Columns: [id, name, nationality, city, latitude, longitude, gender, ethnic.group, age, english.grade, math.grade, sciences.grade, language.grade, portfolio.rating, coverletter.rating, refletter.rating]
# Index: []

# %%
yep.dropna(axis=1) #drops column
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
#      latitude  longitude gender  age  english.grade  math.grade  \
# ...

# %%
yep['name']=1
yep
# Out:
#       id  name               nationality                 city  latitude  \
# 0      0     1                     China               Suzhou     31.31
# 1      1     1  United States of America        Santa Clarita     34.39
# 2      2     1  United States of America              Oakland     37.80
# 3      3     1  United States of America        Castro Valley     37.69
# 4      4     1                    Brazil  São José dos Campos    -23.18
# ..   ...   ...                       ...                  ...       ...
# 302  302     1  United States of America             Columbus     39.96
# 303  303     1  United States of America          Los Angeles     34.05
# 304  304     1  United States of America          Los Angeles     34.05
# 305  305     1  United States of America              Oakland     37.80
# 306  306     1                    Canada              Toronto     43.67
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# ...

# %%
yep['id','name','city']=1      #hwnfind out how
yep
# Out:
#       id  name               nationality                 city  latitude  \
# 0      0     1                     China               Suzhou     31.31
# 1      1     1  United States of America        Santa Clarita     34.39
# 2      2     1  United States of America              Oakland     37.80
# 3      3     1  United States of America        Castro Valley     37.69
# 4      4     1                    Brazil  São José dos Campos    -23.18
# ..   ...   ...                       ...                  ...       ...
# 302  302     1  United States of America             Columbus     39.96
# 303  303     1  United States of America          Los Angeles     34.05
# 304  304     1  United States of America          Los Angeles     34.05
# 305  305     1  United States of America              Oakland     37.80
# 306  306     1                    Canada              Toronto     43.67
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# ...

# %%
# Out:
#       id  name               nationality                 city  latitude  \
# 0      4     2                     China               Suzhou     31.31
# 1      6     2  United States of America        Santa Clarita     34.39
# 2      8     2  United States of America              Oakland     37.80
# 3     10     2  United States of America        Castro Valley     37.69
# 4     12     2                    Brazil  São José dos Campos    -23.18
# ..   ...   ...                       ...                  ...       ...
# 302  608     2  United States of America             Columbus     39.96
# 303  610     2  United States of America          Los Angeles     34.05
# 304  612     2  United States of America          Los Angeles     34.05
# 305  614     2  United States of America              Oakland     37.80
# 306  616     2                    Canada              Toronto     43.67
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# ...

# %%
import pandas as pd
yep1=pd.read_csv(r'C:\Users\Ayan\Desktop\yoo.csv')
merged_col=pd.merge(yep,yep1,on='name')
print(merged_col)
# Out:
#      id_x               name             nationality_x               city_x  \
# 0       0          Kiana Lor                     China               Suzhou
# 1       1     Joshua Lonaker  United States of America        Santa Clarita
# 2       2      Dakota Blanco  United States of America              Oakland
# 3       3    Natasha Yarusso  United States of America        Castro Valley
# 4       4     Brooke Cazares                    Brazil  São José dos Campos
# ..    ...                ...                       ...                  ...
# 302   302        Austin Haas  United States of America             Columbus
# 303   303    Madison Fithian  United States of America          Los Angeles
# 304   304  Zachary Mulvahill  United States of America          Los Angeles
# 305   305   Eliana Michelsen  United States of America              Oakland
# 306   306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
import pandas as pd
yep=pd.read_csv(r'C:\Users\Ayan\Desktop\yoo.csv')
print(yep)
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
f= lambda y: y+2
yep['id']=yep['id'].apply(f)
yep
# Out:
#       id               name               nationality                 city  \
# 0      6          Kiana Lor                     China               Suzhou
# 1      7     Joshua Lonaker  United States of America        Santa Clarita
# 2      8      Dakota Blanco  United States of America              Oakland
# 3      9    Natasha Yarusso  United States of America        Castro Valley
# 4     10     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  308        Austin Haas  United States of America             Columbus
# 303  309    Madison Fithian  United States of America          Los Angeles
# 304  310  Zachary Mulvahill  United States of America          Los Angeles
# 305  311   Eliana Michelsen  United States of America              Oakland
# 306  312    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
import pandas as pd
yep=pd.read_csv(r'C:\Users\Ayan\Desktop\yoo.csv')
print(yep)
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
f= lambda y: y+2
yep['id']=yep['id'].apply(f)
yep
# Out:
#       id               name               nationality                 city  \
# 0      2          Kiana Lor                     China               Suzhou
# 1      3     Joshua Lonaker  United States of America        Santa Clarita
# 2      4      Dakota Blanco  United States of America              Oakland
# 3      5    Natasha Yarusso  United States of America        Castro Valley
# 4      6     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  304        Austin Haas  United States of America             Columbus
# 303  305    Madison Fithian  United States of America          Los Angeles
# 304  306  Zachary Mulvahill  United States of America          Los Angeles
# 305  307   Eliana Michelsen  United States of America              Oakland
# 306  308    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
import pandas as pd
yep=pd.read_csv(r'C:\Users\Ayan\Desktop\yoo.csv')
print(yep)
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
yep.sort_values(by='id',ascending=False)
# Out:
#       id               name               nationality                 city  \
# 306  306    Dane Whittemore                    Canada              Toronto
# 305  305   Eliana Michelsen  United States of America              Oakland
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 303  303    Madison Fithian  United States of America          Los Angeles
# 302  302        Austin Haas  United States of America             Columbus
# ..   ...                ...                       ...                  ...
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 2      2      Dakota Blanco  United States of America              Oakland
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 0      0          Kiana Lor                     China               Suzhou
#
# ...

# %%
yep.sort_values(by='id')
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
filter2 =(yep["id"]>7) & (yep["gender"]=="M")
f1=yep[filter2]
f1
# Out:
#       id                  name               nationality           city  \
# 9      9         Maa'iz al-Dia                    Turkey       Istanbul
# 12    12     Alexander Sherman  United States of America          Omaha
# 13    13         Edgar Sanchez                    Mexico        Tijuana
# 14    14          Kolbi Strunk  United States of America  Mission Viejo
# 18    18            David Pulc                    Canada        Toronto
# ..   ...                   ...                       ...            ...
# 298  298          Nicolas Papp  United States of America       New York
# 299  299  Christopher Inhulsen  United States of America     Fort Worth
# 302  302           Austin Haas  United States of America       Columbus
# 304  304     Zachary Mulvahill  United States of America    Los Angeles
# 306  306       Dane Whittemore                    Canada        Toronto
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# ...

# %%
yep['id']>7
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 302     True
# 303     True
# 304     True
# 305     True
# 306     True
# Name: id, Length: 307, dtype: bool

# %%
fa1=(yep["id"]>8)&(yep["gender"]=="F")&(yep["english.grade"]>3.0)
fa2=yep[fa1]
fa2
# Out:
#       id                name               nationality           city  \
# 10    10      Maja Nicholson  United States of America         Dallas
# 15    15       Brittany Sath                     Japan          Tokyo
# 22    22       Rachel Jambor  United States of America        Chicago
# 25    25      Samantha Hicks  United States of America  Santa Barbara
# 26    26      Angela Harding  United States of America        Manteca
# ..   ...                 ...                       ...            ...
# 293  293   Taryn Springfield                    Canada      Vancouver
# 296  296  Brittany Fernandez                    Mexico         Zamora
# 300  300     Tessa Rawanduzy  United States of America          Derby
# 301  301    Vanessa Gonzalez                 Nicaragua           León
# 303  303     Madison Fithian  United States of America    Los Angeles
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# ...
